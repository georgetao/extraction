# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

import tensorflow as tf
import tensorflow.keras.backend as K

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from flair.embeddings import WordEmbeddings

# %%
# load 
data_path = '../data/context_task_trim.tsv'
data = pd.read_csv(data_path, sep='\t')

# Add start and end tokens
BOS, EOS, OOV, PAD = '_start_', '_end_', '_unk_', '_pad_'
data.Summary = BOS + ' ' + data.Summary + ' ' + EOS

# %%
# test/train split
x_train, x_test, y_train, y_test = train_test_split(
    data.TaskSentence.values, 
    data.Summary.values,
    test_size=0.2,
    random_state=0,
    shuffle=True
)

# %%
# fit tokenizer
MAXLEN = 20

tokenizer = Tokenizer(filters='', lower=True, oov_token = OOV)
tokenizer.fit_on_texts(list(x_train)+list(y_train))

x = tokenizer.texts_to_sequences(x_train)
y = tokenizer.texts_to_sequences(y_train)

x_pad = pad_sequences(x, maxlen=MAXLEN, padding='post')
y_pad = pad_sequences(y, maxlen=MAXLEN, padding='post')

x_val = pad_sequences(
    tokenizer.texts_to_sequences(x_test), 
    maxlen=MAXLEN, 
    padding='post')

y_val = pad_sequences(
    tokenizer.texts_to_sequences(y_test), 
    maxlen=MAXLEN, 
    padding='post')

V = len(tokenizer.word_index) + 1

# %%
# word embeddings
glove_embedding = WordEmbeddings('glove')
EMBEDDING_DIM = glove_embedding.embedding_length

# %%
embedding_matrix = np.zeros((V, EMBEDDING_DIM))

for word, i in tokenizer.word_index.items():
    try:
        word_sent = Sentence(word)
        glove_embedding.embed(word_sent)
        embedding_vector = word_sent[0].embedding.cpu().detach().numpy()
        embedding_matrix[i] = embedding_vector
    except KeyError:
        embedding_matrix[i]=np.random.normal(0,np.sqrt(0.25), EMBEDDING_DIM)

# %%
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Attention, Concatenate, TimeDistributed
from attention import AttentionLayer

# %%
from keras import backend as K 
K.clear_session() 
latent_dim = 100

# make embedding 
# embedding = Embedding(V, EMBEDDING_DIM, weights=[embedding_matrix], trainable=False)

# Encoder 
encoder_inputs = Input(shape=(MAXLEN,)) 
# enc_emb = Embedding(V, latent_dim, trainable=True)(encoder_inputs) 
enc_emb = embedding(encoder_inputs)

#LSTM 1 
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb) 

#LSTM 2 
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True) 
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1) 

#LSTM 3 
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True) 
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2) 

# Set up the decoder. 
decoder_inputs = Input(shape=(None,)) 
# dec_emb = Embedding(V, latent_dim, trainable=True)(decoder_inputs) 
dec_emb = embedding(decoder_inputs)

#LSTM using encoder_states as initial state
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True) 
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c]) 

#Attention Layer
attn_layer = AttentionLayer(name='attention_layer') 
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs]) 

# Concat attention output and decoder LSTM output 
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#Dense layer
decoder_dense = TimeDistributed(Dense(V, activation='softmax')) 
# decoder_dense = Dense(V, activation='softmax')
decoder_outputs = decoder_dense(decoder_concat_input) 

# Define the model
model = tf.keras.Model([encoder_inputs, decoder_inputs], decoder_outputs) 
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, None)]       0
# __________________________________________________________________________________________________
# input_1 (InputLayer)            [(None, 20)]         0
# __________________________________________________________________________________________________
# embedding (Embedding)           multiple             180800      input_1[0][0]
#                                                                  input_2[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 20, 100), (N 80400       embedding[7][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 20, 100), (N 80400       lstm[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 20, 100), (N 80400       lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 100),  80400       embedding[8][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer ((None, None, 100),  20100       lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 200)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 1808)   363408      concat_layer[0][0]
# ==================================================================================================
# Total params: 885,908
# Trainable params: 705,108
# Non-trainable params: 180,800
# __________________________________________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy')

# %%
model.fit(x=[x_pad, y_pad],
          y=np.expand_dims(y_pad, axis=2), 
          batch_size = 128, 
          epochs=20)
# Out:
# Epoch 1/20
# 4/4 [==============================] - 1s 217ms/step - loss: 7.4255
# Epoch 2/20
# 4/4 [==============================] - 1s 193ms/step - loss: 6.8777
# Epoch 3/20
# 4/4 [==============================] - 1s 218ms/step - loss: 5.6929
# Epoch 4/20
# 4/4 [==============================] - 1s 201ms/step - loss: 4.2586
# Epoch 5/20
# 4/4 [==============================] - 1s 200ms/step - loss: 3.0131
# Epoch 6/20
# 4/4 [==============================] - 1s 203ms/step - loss: 2.2963
# Epoch 7/20
# 4/4 [==============================] - 1s 211ms/step - loss: 2.0830
# Epoch 8/20
# 4/4 [==============================] - 1s 198ms/step - loss: 1.9912
# Epoch 9/20
# 4/4 [==============================] - 1s 270ms/step - loss: 1.9473
# Epoch 10/20
# 4/4 [==============================] - 1s 211ms/step - loss: 1.9015
# Epoch 11/20
# 4/4 [==============================] - 1s 182ms/step - loss: 1.8399
# Epoch 12/20
# 4/4 [==============================] - 1s 199ms/step - loss: 1.7941
# Epoch 13/20
# 4/4 [==============================] - 1s 198ms/step - loss: 1.7543
# Epoch 14/20
# 4/4 [==============================] - 1s 200ms/step - loss: 1.7152
# Epoch 15/20
# 4/4 [==============================] - 1s 201ms/step - loss: 1.6798
# Epoch 16/20
# 4/4 [==============================] - 1s 198ms/step - loss: 1.6491
# Epoch 17/20
# 4/4 [==============================] - 1s 200ms/step - loss: 1.6227
# Epoch 18/20
# 4/4 [==============================] - 1s 198ms/step - loss: 1.5998
# Epoch 19/20
# 4/4 [==============================] - 1s 241ms/step - loss: 1.5789
# Epoch 20/20
# 4/4 [==============================] - 1s 233ms/step - loss: 1.5597

# %%
# encoder inference
encoder_model = tf.keras.Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# decoder inference
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(MAXLEN,latent_dim))

# Get the embeddings of the decoder sequence
# dec_emb2 = dec_emb_layer(decoder_inputs)
dec_emb2 = embedding(decoder_inputs)

# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat)

# Final decoder model
decoder_model = tf.keras.Model(
    [decoder_inputs] + [decoder_hidden_state_input, decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

# %%
# def decode_sequence(input_seq):
#     # Encode the input as state vectors.
#     e_out, e_h, e_c = encoder_model.predict(input_seq)

#     # Generate empty target sequence of length 1.
#     target_seq = np.zeros((1,1))

#     # Chose the 'start' word as the first word of the target sequence
#     target_seq[0, 0] = tokenizer.word_index[BOS]

#     stop_condition = False
#     decoded_sentence = ''
#     while not stop_condition:
#         output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

#         # Sample a token
#         sampled_token_index = np.argmax(output_tokens[0, -1, :])
#         sampled_token = tokenizer.index_word[sampled_token_index]
        
#         if(sampled_token is not EOS):
#             decoded_sentence += ' '+sampled_token

#             # Exit condition: either hit max length or find stop word.
#             if (sampled_token == 'end' or len(decoded_sentence.split()) >= (MAXLEN-1)):
#                 stop_condition = True

#         # Update the target sequence (of length 1).
#         target_seq = np.zeros((1,1))
#         target_seq[0, 0] = sampled_token_index

#         # Update internal states
#         e_h, e_c = h, c

#     return decoded_sentence

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)

    # Chose the 'start' word as the first word of the target sequence
    target_seq = np.zeros((1,1))
    target_seq[0, 0] = tokenizer.word_index[BOS]

    sent = ''
    while True:
        
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        token_index = np.argmax(output_tokens[0, -1, :])
        token = tokenizer.index_word[token_index]
        
        if token == EOS or len(sent.split()) >= MAXLEN-1:
            break
        
        # append 
        sent += ' '+token

        # Update the target sequence (of length 1).
        target_seq[0, 0] = token_index

        # Update internal states
        e_h, e_c = h, c

    return sent

# %%
def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=tokenizer.word_index[BOS]) and i!=tokenizer.word_index[EOS]):
            newString = newString + tokenizer.index_word[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString = newString + tokenizer.index_word[i]+' '
    return newString

# %%
tokenizer.index_word[0] = PAD

# %%
seq2text(x_pad[300])
# Out:
# 'please destroy your current card and replace it with the new wallet card upon receipt. '

# %%
decode_sequence(np.expand_dims(x_pad[300], axis=0))
# Out:
# ' _start_ _start_ _start_ _pad_ _pad_ _pad_ _pad_ _pad_ _pad_ _pad_ _pad_ _pad_ _pad_ _pad_ _pad_ _pad_ _pad_ _pad_ _pad_'

# %%
a =  embedding_matrix[tokenizer.word_index['send']]
b =  embedding_matrix[tokenizer.word_index['give']]
np.dot(a,b) / (np.linalg.norm(a)*np.linalg.norm(b))
# Out:
# 0.7272412382771437

# %%
# tokenizer.index_word

# %%
for i in range(len(x_pad)):
    print("TaskSentence: ", seq2text(x_pad[i]))
    print("Original summary:" , seq2summary(y_pad[i]))
    print("Predicted summary:", decode_sequence(x_val[i].reshape(1,max_len_text)))
    print("\n")
# Out:
# TaskSentence:  Please respond to Chris Germany@enron.com
# Original summary: Reply to Chris at Germany@enron.com
#
#
# TaskSentence:  Please take a look at this and give me a call.
# Original summary: Examine this and call SENDER
#
#
# TaskSentence:  Please take a few minutes to completely fill out the following survey.
# Original summary: Complete survey
#
#
# TaskSentence:  Please review and send comments to Mollie Lampi mlampi@nyiso.com by 10:00 AM Friday morning 12/1 .
# Original summary: Review filing with the FERC and send coments to Mollie Lampi
#
#
# TaskSentence:  Please make review and if you have any modifications, please get with John as soon as possible.
# Original summary: Review Alberta PPA presentation
#
#
# TaskSentence:  And lastly, can you put me on cc: list for Wellesley info.
# Original summary: Put SENDER on cc list for Wellesley
#
#
# TaskSentence:  To view the Group members, please open the ECT Address book, click on Groups, then double-click on the name of the group.
# Original summary: Open ECT Address Book
#
#
# TaskSentence:  I realize we are dealing with numerous cuts and renoms during the day, but if at all possible, please try to attend.
# Original summary: Attend meeting about responsibilities in maintaining the Kerr McGee tickets in Sitara
#
#
# TaskSentence:  Please insert appropriate Seller's Payment if minus 018 is used in Contract Price and if Customer is the Seller.
# Original summary: Insert appropriate Seller's Payment
#
#
# TaskSentence:  Can you take a look?
# Original summary: Look at definition for diesel index
#
#
# TaskSentence:  Please donate this money to the funds set up to help repair the lives of those Americans hurt by Enron's underhanded dealings.
# Original summary: Donate this money
#
#
# TaskSentence:  Greetings Diane: Could you check the work phone for Joseph Brophy.
# Original summary: Check work phone for Joseph Brophy
#
#
# TaskSentence:  Please call me or Tracy Cummins at 713-8566-525 with any questions.
# Original summary: Call SENDER or Tracy Cummins at 713-8566-525
#
#
# TaskSentence:  Give me a call.
# Original summary: Call SENDER about March Aeco product
#
#
# TaskSentence:  Please supply Portland at their system in the most cost effective manner possible.
# Original summary: Supply Portland at their system
#
#
# TaskSentence:  Can you meet with us tomorrow?
# Original summary: Meet with SENDER tomorrow
#
#
# TaskSentence:  Please create today the September GDD/IF swap and the september Gas Daily Henry Hub swap.
# Original summary: Create swaps today
#
#
# TaskSentence:  Please run the minibook requested below and forward to Ellen.
# Original summary: Run minibook and forward to Ellen
#
#
# TaskSentence:  Please scroll down
# Original summary: Scroll down
#
#
# TaskSentence:  give me a call on my cell and we can meet up there.
# Original summary: Call SENDER
#
#
# TaskSentence:  Please include Rey in your quest for closure.
# Original summary: Include Rey in quest for closure
#
#
# TaskSentence:  Don can you try and find a time next week with Lew for me to have dinner - get Beverly to schedule the plane to get me in and out that day.
# Original summary: Coordinate with Lew about SENDER's dinner
#
#
# TaskSentence:  Could you please approve HSC Basis for Oct?
# Original summary: Approve HSC Basis for Oct
#
#
# TaskSentence:  Please update your personal GIS file by FRIDAY, MARCH 31.
# Original summary: Update personal GIS file
#
#
# TaskSentence:  Please call me so we can staighten out the deal or you can call Laura Scott in Canada and argue your point.
# Original summary: Call SENDER
#
#
# TaskSentence:  Please inform me on this.........
# Original summary: Inform SENDER of this
#
#
# TaskSentence:  Please review the instructions attached to each PSA.
# Original summary: Review instructions
#
#
# TaskSentence:  Please forward your copy of GTAnet to anyone you think might find the issue useful.
# Original summary: Forward copy of GTAnet to anyone who might find the issue useful
#
#
# TaskSentence:  Can you please forward me the cost centre to which this FedEx bill should be charged to.
# Original summary: Forward cost centre to SENDER
#
#
# TaskSentence:  Dee, could you please forward to Steve Van Hooser our usual checklist on employee matters for diligence purposes?
# Original summary: Forward this to Steve Van Hooser
#
#
# TaskSentence:  Could you spare a few moments to look over the attached three-page Power Point presentation?
# Original summary: Review Power Point presentation
#
#
# TaskSentence:  Check out the site - http://enron.referrals.com/promo.asp - let us know what you think -- we want to hear from you.
# Original summary: Check out http://enron.referrals.com/promo.asp
#
#
# TaskSentence:  You can either call me on my cell or have Jeanie walk list across.
# Original summary: Call SENDER
#
#
# TaskSentence:  I am interested in the crib , please give me a call.
# Original summary: Call SENDER about crib
#
#
# TaskSentence:  I asked Keegan to get Kate Cole's signatures for the Consent Form so please follow up to get that form from Keegan.
# Original summary: Get Conset Form from Keegan
#
#
# TaskSentence:  Call me to discuss these issues.
# Original summary: Call SENDER
#
#
# TaskSentence:  Rob, please follow up with Dorie she will handle the process for you.
# Original summary: Follow up with Dorie
#
#
# TaskSentence:  Please send the current DRAFT to the User's Guide to 1999 ISDA Credit Derivatives Definitions to my attention.
# Original summary: Send current DRAFT to SENDER
#
#
# TaskSentence:  PLEASE REVIEW THE NOTICE AND DISCLAIMER BELOW
# Original summary: Review notice and disclaimer
#
#
# TaskSentence:  As you are probably aware, we have experienced difficulty reaching the radio stations in the past so please call one of the numbers listed above if you don't hear an announcement on the radio.
# Original summary: Call 3987-000 , 3987-200 or 3987-700
#
#
# TaskSentence:  shoot me back an email when you get a chance.
# Original summary: Email SENDER
#
#
# TaskSentence:  If the changes are acceptable, please print out two originals for execution by ENA and overnight to me for execution by Cinergy.
# Original summary: Print originals and overnight them to SENDER
#
#
# TaskSentence:  Ina: Can you set up a 5 minute mtg with me and all of the assistants and runners in regards to what we discussed this week
# Original summary: Schedule meeting with SENDER and assistants
#
#
# TaskSentence:  Give me a call because I really want this to happen.
# Original summary: Call SENDER
#
#
# TaskSentence:  Doug: Please talk with Mark Taylor on who should handle this in our group as given my situation, I will probably not be able to take this on.
# Original summary: Talk with Mark Taylor
#
#
# TaskSentence:  Could you give me a brief description of what this is?
# Original summary: Describe this for SENDER
#
#
# TaskSentence:  Please replace the current section 5.4 in the Calpine O&M with the attached.
# Original summary: Replace current section with the attached
#
#
# TaskSentence:  Please respond to her and copy me if via email with your response to the proposed changes.
# Original summary: Reply to Carol St. Clair and copy SENDER
#
#
# TaskSentence:  Kay, please have Jordan forward this in hard copy to your attention.
# Original summary: Get this in hard copy from Jordan
#
#
# TaskSentence:  If you could also please copy Brian and myself with that e-mail so each of us have the most recent versions for when we revisit the structure next week.
# Original summary: Copy Brian and SENDER on email
#
#
# TaskSentence:  Please see the latest revision to the proposed MOU.
# Original summary: Examine latest revision to proposed MOU
#
#
# TaskSentence:  Please tell him to clarify which cp with the broker as the trade is being done.
# Original summary: Tell Tom to clarify the cp
#
#
# TaskSentence:  Please respond to a jimenezcrespo@mailcity.com
# Original summary: Reply to jimenezcrespo@mailcity.com
#
#
# TaskSentence:  However, PADI and the diving industry do need your help in another way.
# Original summary: Helo PADI and driving industry
#
#
# TaskSentence:  Please respond to korydegan4034@publicist.com
# Original summary: Reply to korydegan4034@publicist.com
#
#
# TaskSentence:  Please, register me for this.
# Original summary: Register SENDER for this
#
#
# TaskSentence:  Can you please handle and ensure this is processed today.
# Original summary: Ensure this is processed today
#
#
# TaskSentence:  Ben/Fred/Rebecca, could you please prepare a draft of the two exhibits?
# Original summary: Prepare draft of exhibits
#
#
# TaskSentence:  When you distribute your respective weekly/monthly reports O&M, Capex, P&L , could you please forward them to Jinsung Myung and Ben Rogers, so that they can generate the weekly report that I have been generating while I am gone.
# Original summary: Forward reports to Jinsung Myung and Ben Rogers
#
#
# TaskSentence:  Please re-issue today.
# Original summary: Reissue this today
#
#
# TaskSentence:  Pls coordinate a vacation schedule planner for me for all of the staff from now until the end of the year including Jan .
# Original summary: Coordinate a vacation schedule planner
#
#
# TaskSentence:  Please follow the steps to reset and synchronize your passwords.
# Original summary: Follow steps to reset password
#
#
# TaskSentence:  If you are interested in learning more about the Hedge Fund industry and how to get into the profession, what is the career path for someone in this field, please plan on attending this incite full presentation.
# Original summary: Attend presentation
#
#
# TaskSentence:  Please call Richard Sage to find out if there are particular names we should use for the various officers or whether they are simply the same as for ENA.
# Original summary: Call Richard Sage
#
#
# TaskSentence:  Please respond to freephonecalls@postaweb.com
# Original summary: Reply to freephonecalls@postaweb.com
#
#
# TaskSentence:  Can you please call Dale Onrait at 250-7122-195 and have him liquidate the Canadian positions and tell him you would like the proceeds and the Candian cash to be converted to US dollars and transfered to RBC Dain Rauscher.
# Original summary: Call Dale Onrait at 250-7122-195
#
#
# TaskSentence:  Please follow up with this.
# Original summary: Follow up with this
#
#
# TaskSentence:  Please donate this money to the funds set up to help repair the lives of those Americans hurt by Enron's underhanded dealings.
# Original summary: Donate this money
#
#
# TaskSentence:  Can you check into this and see what happened?
# Original summary: Investigate this deal
#
#
# TaskSentence:  Please donate this money to the funds set up to help repair the lives of those Americans hurt by Enron's underhanded dealings.
# Original summary: Donate this money
#
#
# TaskSentence:  Could you kindly please offer me some real weather data information about the price peak or plummet because of the weather conditions?
# Original summary: Offer weather data information to SENDER
#
#
# TaskSentence:  Please indicate your preferences on this form and return it to me by e-mail or by fax or please feel free to call .
# Original summary: Indicate preferences on form
#
#
# TaskSentence:  1999. Please update your records.
# Original summary: Update your records
#
#
# TaskSentence:  Take a look at the e-mail below and see if we can suport them.
# Original summary: Examine e-mail below
#
#
# TaskSentence:  Effective 3/1/2000, please increase our nom to 60,000 MMBtu per day into Eastrans.
# Original summary: Increase nom to 60,000 MMBtu
#
#
# TaskSentence:  If you would like to identify yourself, please submit your name and phone number with your letter or message.
# Original summary: Submit name and phone number
#
#
# TaskSentence:  Would you please get the necessary information to Susan Wimberly so that we can get this straightened out in PEP and in the GCS as soon as possible?
# Original summary: Send necessary information to Susan Wimberly
#
#
# TaskSentence:  PLEASE CALL 973-3760-005 ask for Order Dept.www.winelibrary.com or e-mail us at swl@winelibrary.com 1.
# Original summary: Call 973-3760-005
#
#
# TaskSentence:  Maureen please check my calendar
# Original summary: Check SENDER's calendar
#
#
# TaskSentence:  I think you are pretty busy over the next few days--please respond as your schedule allows.
# Original summary: Reply to SENDER
#
#
# TaskSentence:  If you would like to see the form of this label or have other questions, please email Heather at hmathis@enron.com or call her at 713-8539-006 .
# Original summary: Contact Heather at hmathis@enron.com
#
#
# TaskSentence:  Could you put together a list of all the Enron Corp employees who have Enron non-Dell equipment at home.
# Original summary: Compile list of employees who have Enron non-Dell equipment at home
#
#
# TaskSentence:  Susan: would you please respond to this trader?
# Original summary: Reply to this trader
#
#
# TaskSentence:  Mary, Could you please prepare the form of CA for these entities.
# Original summary: Prepare form of CA
#
#
# TaskSentence:  Please review for possible signing by Steve Harris on today.
# Original summary: Review SW Gas Proposals for signing today
#
#
# TaskSentence:  Please make comments and send back.
# Original summary: Send comments on pitch book to SENDER
#
#
# TaskSentence:  Please ensure you and Daren have met prior to the meeting, and you are prepared to represent this functional area.
# Original summary: Meet with Daren and prepare to represent this functional area
#
#
# TaskSentence:  So please double check with Vince on this.
# Original summary: Check this with Vince
#
#
# TaskSentence:  PLEASE FORWARD TO ANYONE APPROPRIATE:
# Original summary: Forward this to anyone appropriate
#
#
# TaskSentence:  Please provide comments to the project director Amy Jaffe or the task force chair Ed Morse.
# Original summary: Provide comments to Amy Jaffe or Ed Morse
#
#
# TaskSentence:  Please email me with requests for central deals.
# Original summary: Email SENDER requests for central deals
#
#
# TaskSentence:  Also, please let Russell Diamond know when this is sent out and whether we get their faxed signature back.
# Original summary: Inform Russel and Diamond when Spot Confirm is sent out
#
#
# TaskSentence:  Susan: Please change the signature block as set forth below and I'll review.
# Original summary: Change signature block
#
#
# TaskSentence:  Please call me when you have a chance.
# Original summary: Call SENDER
#
#
# TaskSentence:  Could you please give me access to the west desk info.
# Original summary: Give access to west desk info to SENDER
#
#
# TaskSentence:  If you have any questions, please call the Development Center Team at 713-8530-357 .
# Original summary: Call the Development Center Team at 713-8530-357
#
#
# TaskSentence:  Please review and if acceptable you can forward to Devon for review.
# Original summary: Review Confirm and GTC
#
#
# TaskSentence:  Can you e-mail to me the new Canadian Annex?
# Original summary: Send Canadian Annex to SENDER
#
#
# TaskSentence:  Consequently, PLEASE RETAIN any and all documents, including all drafts, electronic documents, and email, that relate in any fashion to the 8K filing.
# Original summary: Retain all documents about filing
#
#
# TaskSentence:  Email me when you get in.
# Original summary: Email SENDER
#
#
# TaskSentence:  Please confirm your attendance at this meeting.
# Original summary: Confirm attendance at The Enron Wholesale Markets Quarterly Legal Review for Power Trading
#
#
# TaskSentence:  Please coordinate with John Nowlan, Chris Mahoney, and John Chismar respectively.
# Original summary: Coordinate with John Nowlan, Chris Mahoney, and John Chismar
#
#
# TaskSentence:  Please open the document.
# Original summary: Open document
#
#
# TaskSentence:  Please review and let's discuss further before forward by to Cascade.
# Original summary: Review Cascade Documents
#
#
# TaskSentence:  Check out the latest version of Enron Business Online at home.enron.com.
# Original summary: See latest version of Enron Business Online
#
#
# TaskSentence:  Please review and let me know if it makes sense, and then I will send you, Scott, Richard Park, and Tom Swank.
# Original summary: Review this
#
#
# TaskSentence:  Kate, Richter please check 506503.01 Enron Sells SCEM/Mirant
# Original summary: Check 506503.01 Enron Sells
#
#
# TaskSentence:  Please follow up on this.
# Original summary: Follow up on this
#
#
# TaskSentence:  Per my voice mail, please respond about RMT vs. ENA.
# Original summary: Reply to SENDER about RMT vs. ENA
#
#
# TaskSentence:  I am preparing for the final signoff phase on the graphics and practice questions and I need your help finalizing the scenarios that we talked about two weeks ago for Futures and Options.
# Original summary: Help finalize scenarios for Futures and Options
#
#
# TaskSentence:  Please plan to have the gas rerouted back down the valley line for the Dec 1 forward.
# Original summary: Plan to have gas rerouted back down the valley
#
#
# TaskSentence:  Please email everyone with the end date when you find out.
# Original summary: Email everyone with end date
#
#
# TaskSentence:  If you made an update during this period, please return to eHRonline and review your information particularly for the following four categories: Banking information for direct deposit Tax W-4 information Home address Emergency contact
# Original summary: Review your information on eHRonline
#
#
# TaskSentence:  Please print the messages below.
# Original summary: Print the messages
#
#
# TaskSentence:  Andy - can you please forward this email to your book person to change these attached deals from ENA- PGL to ENA - and the actual counterparty.
# Original summary: Forward email to book person to change deals
#
#
# TaskSentence:  Please send a credit worksheet for financial trading and we can deliver a draft ISDA to the lawyer per Stewart's instructions.
# Original summary: Send a credit worksheet to SENDER
#
#
# TaskSentence:  Please call Ben Jacoby to get things going.
# Original summary: Call Ben Jacoby
#
#
# TaskSentence:  Paul, please provide the dollar amount needed in the blank below.
# Original summary: Provide dollar amountn in email
#
#
# TaskSentence:  Please donate this money to the funds set up to help repair the lives of those Americans hurt by Enron's underhanded dealings.
# Original summary: Donate this money
#
#
# TaskSentence:  Please call me at 713-8533-399 or Bob at 713-8530-397 if you have any comments or questions.
# Original summary: Call SENDER at 713-8533-399
#
#
# TaskSentence:  Jeff Gossett is adamant about getting the financial liquidation variances cleared before next month and we really need your help resolving these.
# Original summary: Help resolve variances.
#
#
# TaskSentence:  If you need further assistance with your ID or password, please contact the ISC Call Center at 713-3454-727 .
# Original summary: Call ISC Call Center at 713-3454-727
#
#
# TaskSentence:  Please review the attached non-standard discount letter for Duke Energy Trading & Marketing.
# Original summary: Review attached letter
#
#
# TaskSentence:  Could you please respond as soon as possible to this email or directly to Bonnie White if you know of any reason why ENA should not go forward with filing this suit.
# Original summary: Reply to SENDER
#
#
# TaskSentence:  Please include the transactions by desk sheets?
# Original summary: Include transactionns by desk sheets
#
#
# TaskSentence:  As you are probably aware, we have experienced difficulty reaching the radio stations in the past so please call one of the numbers listed above if you don't hear an announcement on the radio.
# Original summary: Call 3987-000, 3987-200 or 3987-700
#
#
# TaskSentence:  Please distribute this memorandum to others involved in the confirmation process, as appropriate, and feel free to call me at X34718 if you have any questions or comments.
# Original summary: Distribute memorandum to others involved
#
#
# TaskSentence:  Please call me to discuss.
# Original summary: Call SENDER
#
#
# TaskSentence:  Please review and provide your thoughts.
# Original summary: Review draft of 20/20 Term Sheet
#
#
# TaskSentence:  Can you please make this change for me.
# Original summary: Change this for SENDER
#
#
# TaskSentence:  Please notify us immediately by reply e-mail and then delete this message from your system.
# Original summary: Notify SENDER by reply e-mail
#
#
# TaskSentence:  Please contact the ISC Call Center at 713-3454-727 .
# Original summary: Call ISC Call Center at 713-3454-727
#
#
# TaskSentence:  If you are not an intended recipient of this message, please do not read, copy or disclose the contents of this communication to others and please notify the sender at 713-2077-414 .
# Original summary: Do not read contents of this commuication
#
#
# TaskSentence:  Also, please check on the kingsgate to malin and stanfield to malin for next month.
# Original summary: Check on kingsgate to malin and stanfield to malin
#
#
# TaskSentence:  Please, put on my schedule and confirm.
# Original summary: Put this on SENDER's schedule
#
#
# TaskSentence:  Please call the upstream DETM OR CORAL to confirm that the schedule is being filled each hour.
# Original summary: Call upstream DETM OR CORAL
#
#
# TaskSentence:  Can you update me?
# Original summary: Update SENDER on trades
#
#
# TaskSentence:  Mark, Please send me the March Risk numbers.
# Original summary: Send March Risk numbers to SENDER
#
#
# TaskSentence:  Guys, please mark your calendars for the 2000 ENA Management Offsite scheduled for December 14th and 15th at the Venetian in Las Vegas.
# Original summary: Put 2000 ENA Management Offsite on calendar
#
#
# TaskSentence:  Tim, it is all yours please communicate ASAP to Jana Jovanni in the A&A program.
# Original summary: Communicate with Jana Jovanni
#
#
# TaskSentence:  Please, check the logic of my modifications I hope I copied all the formulas correctly .
# Original summary: Check logic of modifications
#
#
# TaskSentence:  PLEASE REVIEW THE NOTICE AND DISCLAIMER BELOW
# Original summary: Reiview notice and disclaimer
#
#
# TaskSentence:  Kay: Please forward an executed copy of CO#2 so we can continue issuing Change Orders.
# Original summary: Forward a copy of CO#2 to SENDER
#
#
# TaskSentence:  Please supply Portland at their system in the most cost effective manner possible.
# Original summary: Supply Portland at their system
#
#
# TaskSentence:  Please print all three documents for your hard copies.
# Original summary: Print documents of interview packet
#
#
# TaskSentence:  If at all possible will you please have the first draft of this document completed this Friday, May 19th.
# Original summary: Complete first draft by Friday, May 19th
#
#
# TaskSentence:  Could you do this again for me please.
# Original summary: Do this again
#
#
# TaskSentence:  Please respond to Chris Strickland chris@lacimagroup.com
# Original summary: Reply to Chris Strickland at chris@lacimagroup.com
#
#
# TaskSentence:  Should it be the case that you require continued delivery from, and Online access to, PIRA's services, please respond to this email or contact Jeff Steele at 212-6866-808 , or jsteele@pira.com.
# Original summary: Contact Jeff Steele at 212-6866-808
#
#
# TaskSentence:  It's called Unsung Hero and I know we all have one of those in our lives.. check this out and see what they have to offer.
# Original summary: Look at Unsung Hero
#
#
# TaskSentence:  If you have any questions about the work schedules or anything thing else, give me a call.
# Original summary: Call SENDER about work schedules
#
#
# TaskSentence:  Review the space plans and give your comments
# Original summary: Review space plans
#
#
# TaskSentence:  If acceptable in your view, please proceed with execution.
# Original summary: Execute it
#
#
# TaskSentence:  Please review the following ticketed itinerary
# Original summary: Review ticked itinerary
#
#
# TaskSentence:  Could you please resend it?
# Original summary: Send email to SENDER
#
#
# TaskSentence:  Mark: Please verify for me that you told Susan F. that Samantha would be responsible for the brokerage accounts when she joins us.
# Original summary: Verify Susan F. knows Samantha is responsible for brokerage accounts
#
#
# TaskSentence:  Could just send me a quick e-mail, and copy Bill Williams III real time manager , when you change deals under the Short Term West Hourly desk?
# Original summary: Copy Bill Willaims III on email to SENDER
#
#
# TaskSentence:  Please provide these three charts and any changes you might have by Friday, 9/15.
# Original summary: SEND charts to SENDER by Friday, 9/15
#
#
# TaskSentence:  Please review the attached and give me a call.
# Original summary: Review attached document and call SENDER
#
#
# TaskSentence:  Please coordinate with Sharon.
# Original summary: Coordinate with Sharon
#
#
# TaskSentence:  Please approve and autoschedule.
# Original summary: Approve and autoschedule this
#
#
# TaskSentence:  In my absence please contact Barbara for coordination of legal support in the event you cannot wait until I return.
# Original summary: Contact Barbara for coordination of legal support
#
#
# TaskSentence:  Please contact John Lavorato.
# Original summary: Contact John Lavorato
#
#
# TaskSentence:  CP, please followup on the 2 email failure messages and delete.
# Original summary: Reply to SENDER about email failure messages
#
#
# TaskSentence:  Please direct all comments to the CMR Recommendation to the Board to Byron Woertz at bwoertz@caiso.com
# Original summary: Send comments to CMR
#
#
# TaskSentence:  Fran, could you work with Emily and find a time?
# Original summary: Coordinate with Emily
#
#
# TaskSentence:  Please have a look at it and let me what additional changes are needed.
# Original summary: Review revision of Kaiser Agency Agreement
#
#
# TaskSentence:  Please donate this money to the funds set up to help repair the lives of those Americans hurt by Enron's underhanded dealings.
# Original summary: Donate this money
#
#
# TaskSentence:  Please respond by 10 a.m. on Wednesday, November 8.
# Original summary: Reply to SENDER
#
#
# TaskSentence:  Please add Janice Moore and Shari Stack to you list and delete Lou Stoler.
# Original summary: Add Janice Moore and Shari Stack to list and delete Lou Stoler
#
#
# TaskSentence:  Give me a call when you get a chance.
# Original summary: Call SENDER
#
#
# TaskSentence:  Please send your comments to Joe Tambornino, tamborni@haas.berkeley.edu, by Tuesday the 5th, and we will endeavor to supply you with THE UNOFFICIAL GUIDE TO HAAS SPRING ELECTIVES by the end of the week, which shall include commentary, course descriptions, information on new professors, etc.
# Original summary: Send comments to Joe Tamborino at tamborni@haas.berkeley.edu by Tuesday the 5th
#
#
# TaskSentence:  Please check the last couple of pages and see if I'm close.
# Original summary: Check pages
#
#
# TaskSentence:  Give me a call.
# Original summary: Call SENDER
#
#
# TaskSentence:  Please respond to paul rodrigue@bigfoot.com
# Original summary: Reply to paul at paul rodrigue@bigfoot.com
#
#
# TaskSentence:  Please get me Pat Wood's phone number and post a reminder on my calendar to call him ASAP
# Original summary: Send Pat Woods's number to SENDER and post calendar reminder
#
#
# TaskSentence:  Would you research this please?
# Original summary: Research this
#
#
# TaskSentence:  Please take me off you distribution.
# Original summary: Remove SENDER from distribution
#
#
# TaskSentence:  I am flying back to Portland tomorrow morning at about 9:30 arriving at 12:00 Please call me at 503-8078-959 or e-mail me w/ and update on you talks w/ CSC.
# Original summary: Call SENDER at 503-8078-959
#
#
# TaskSentence:  If at all possible will you please have the first draft of this document completed this Friday, May 19th.
# Original summary: Complete first draft by Friday, May 19th
#
#
# TaskSentence:  Please respond as soon as possible so that we can chack out this week.
# Original summary: Reply to SENDER
#
#
# TaskSentence:  Jere, please forward the list of targets.
# Original summary: Forward lists of targets to SENDER
#
#
# TaskSentence:  Please make your check payable to National MS Society, and send it to me at EB5008A at your convenience.
# Original summary: Send check to SENDER at EB5008A
#
#
# TaskSentence:  Fran, can you sign me up for the Leadership Training on 10/31-11/02?
# Original summary: Sign up SENDER for Leadership Training
#
#
# TaskSentence:  Please send me an electronic copy of the document provided to the city attorney on Monday.
# Original summary: Send copy of document provided to the city attorney to SENDER
#
#
# TaskSentence:  Please verify the language in the attached document, make any necessary changes and return to me.
# Original summary: Verify language in attached document
#
#
# TaskSentence:  Please forward things to me.
# Original summary: Forward things to SENDER
#
#
# TaskSentence:  Please configure their access for both floors and then confirm back to us when completed.
# Original summary: Give every on list access to both floors
#
#
# TaskSentence:  Please use 503-4642-663 to participate in all of the meetings listed below.
# Original summary: Participate in meetings with 503-4642-663
#
#
# TaskSentence:  If in agreement, please print out two originals, have both signed and send same to my attention for final signature.
# Original summary: Print originals and have them signed
#
#
# TaskSentence:  Please log off of your machines tonight.
# Original summary: Log off of machine
#
#
# TaskSentence:  Please make sure this is clearly understood by the schedulers.
# Original summary: Ensure schedulers understand this
#
#
# TaskSentence:  Will you please create a new product that reads as follows:
# Original summary: Create new product
#
#
# TaskSentence:  Please put this on my calendar.
# Original summary: Put this on SENDER's calendar
#
#
# TaskSentence:  Kaye: Will you please print these docs for me?
# Original summary: Pring docs
#
#
# TaskSentence:  Please call me at 35777 with any questions.
# Original summary: Call SENDER at 35777
#
#
# TaskSentence:  Please contact me at your earliest convenience at 713-8531-586 .
# Original summary: Call SENDER at 713-8531-586
#
#
# TaskSentence:  Please give me a call when you return to your office.
# Original summary: Call SENDER
#
#
# TaskSentence:  Can you please review these slight revisions and pass this back to me.
# Original summary: Review revisions
#
#
# TaskSentence:  To send a message to all the people currently subscribed to the list, just send mail to FRBNYRMAG1@PEACH.EASE.LSOFT.COM.
# Original summary: Email FRBNYRMAG1@PEACH.EASE.LSOFT.COM
#
#
# TaskSentence:  Please, send the bio.
# Original summary: Send bio to SENDER
#
#
# TaskSentence:  Please follow up with chris.
# Original summary: Follow up with chris
#
#
# TaskSentence:  David Hunt drhunt@watervalley.net on 06/01/2001 05:01:40 PM Please respond to drhunt@watervalley.net To: Kay.Mann@enron.com cc:
# Original summary: Reply to drhunt@watervalley.net
#
#
# TaskSentence:  Please donate this money to the funds set up to help repair the lives of those Americans hurt by Enron's underhanded dealings.
# Original summary: Donate this money
#
#
# TaskSentence:  Please take a look to see if any changes are needed.
# Original summary: Examine this
#
#
# TaskSentence:  4. Can you negotiate .
# Original summary: Negotiate
#
#
# TaskSentence:  Can you just send 3 or 4 for this meeting and I will set up a secondary date for the others.
# Original summary: Send 3 or 4 for this meeting
#
#
# TaskSentence:  Please use the following two files as your detail support for finanical liquidations:
# Original summary: Use files as detail support
#
#
# TaskSentence:  Please call me if you would like to discuss.
# Original summary: Call SENDER
#
#
# TaskSentence:  Please remove her from all your mail lists.
# Original summary: Remove Mary Hain from mail lists
#
#
# TaskSentence:  Can you look into this please?
# Original summary: Look into this deal
#
#
# TaskSentence:  Please, send me your fax # for more info.
# Original summary: Send fax number to SENDER
#
#
# TaskSentence:  Please complete the survey by clicking on the link below by Thursday, February 8th.
# Original summary: Complete survey
#
#
# TaskSentence:  I just want to ask you if you could send me over the mail the latest forward curves so that we use them to update our long-term plan.
# Original summary: Send mail from latest forward curves to SENDER
#
#
# TaskSentence:  Please co-ordinate with Robert and make sure that someone sends him a nice rejection letter.
# Original summary: Coordinate with Robert about rejection letter
#
#
# TaskSentence:  PLEASE FORWARD YOUR SHIRT SIZE TO ME S, M, L, XL, ETC. AS SOON AS POSSIBLE,
# Original summary: Send shirt size to SENDER
#
#
# TaskSentence:  VIEW AND SHARE: View your photos in thumbnail size or larger views, share a roll, e-mail select pictures, download photos, send a photo photo postcard, or add a caption.
# Original summary: View photos
#
#
# TaskSentence:  Call me a NX1 68 offer for the term and volumes listed.
# Original summary: Cal SENDER
#
#
# TaskSentence:  Can you please check Sean or Dianna book because I have it checked as verballed but now they are saying it is not there deal.
# Original summary: Check Sean or Dianna book
#
#
# TaskSentence:  Please donate this money to the funds set up to help repair the lives of those Americans hurt by Enron's underhanded dealings.
# Original summary: Donate this money
#
#
# TaskSentence:  Please forward to public affairs group.
# Original summary: Forward this to public affairs group
#
#
# TaskSentence:  Louise, will you please review at least your portion?
# Original summary: Review your portion
#
#
# TaskSentence:  Please notify Lisa Lees when you send out the final execution copy to Talisman for signature.
# Original summary: Notify Lisa Lees when sending out final execution copy to Talisman
#
#
# TaskSentence:  User ID: emclaug Password: emclaug Please Change
# Original summary: Change password
#
#
# TaskSentence:  When you have a chance, please take a look at the attached.
# Original summary: Examine attached document
#
#
# TaskSentence:  Please give me a two or three sentence summary of the trading issue and court decision thereon in Blue Range.
# Original summary: Send summary of trading issue and court decision to SENDER
#
#
# TaskSentence:  Don please follow up to see if this product has any value to us.
# Original summary: Follow up with SENDER about this product
#
#
# TaskSentence:  Please, ask Shirley to resubmit.
# Original summary: Ask Shirley to resubmit request
#
#
# TaskSentence:  Mark, can you participate in the ISDA call on Friday?
# Original summary: Participate in ISDA call on Friday
#
#
# TaskSentence:  Please activate the following long list of products:
# Original summary: Activate this list of products
#
#
# TaskSentence:  Please coordinate public statements, interviews, and the like through the proper channels going forward.
# Original summary: Coordinate statements and interviews through proper channels
#
#
# TaskSentence:  Please include Scott Goodell on all responses.
# Original summary: Include Scott Goodell on all responses
#
#
# TaskSentence:  please schedule
# Original summary: Please schedule
#
#
# TaskSentence:  can you check with bob again, because i got confirms on the deals.
# Original summary: Check with bob
#
#
# TaskSentence:  Please send all four contracts directly to John Peyton at EB 3584B.
# Original summary: Send contacts to John Peyton at EB 3584B
#
#
# TaskSentence:  Glenda, per our conversation on this morning, please complete the following request for the TW Commercial Group:
# Original summary: Complete this request
#
#
# TaskSentence:  Please address Cooper's questions, or forward to the Calgary office.
# Original summary: Address Cooper's questions
#
#
# TaskSentence:  Otherwise why don't you just call me at the room when you get to the hotel.
# Original summary: Call SENDER from hotel
#
#
# TaskSentence:  Please send them to Peter Keohane's new assistant, Sharon Crawford.
# Original summary: Send copies of Canadian agreements to Sharon Crawford
#
#
# TaskSentence:  Please go through this and run the sensitivities and get a good idea of way to structure thsi.
# Original summary: Review comments in document and run sensitivities
#
#
# TaskSentence:  Please forward this on.
# Original summary: Forward this on
#
#
# TaskSentence:  Gerald, Please comment on section 1.6 of the attached document.
# Original summary: Comment on section 1.6 of the document
#
#
# TaskSentence:  Please respond to websupport@moneynet.com
# Original summary: Reply to websupport@moneynet.com
#
#
# TaskSentence:  Please respond to kaplan
# Original summary: Reply to Kaplan
#
#
# TaskSentence:  I understand that your legal department has comments to our form; if you could please send those to my attention, I would appreciate it.
# Original summary: Send comments from legal department to SENDER
#
#
# TaskSentence:  Please make sure that your email address is at the end of the url.
# Original summary: Ensure email address is at the end of the url
#
#
# TaskSentence:  Steve, please add Victor and myself to your email distribution.
# Original summary: Add SENDER and Victor to email distribution
#
#
# TaskSentence:  Please review the POGO work order at N:/homedept/facility/tw/tw 2001/pogo
# Original summary: Review POGO work order
#
#
# TaskSentence:  Could you please look through these names and let us know if you approve.
# Original summary: Look through these names
#
#
# TaskSentence:  If you would like to stop receiving e-mail notifications when your publications are available, please reply to this message with REMOVE E-MAIL in the subject line.
# Original summary: Reply to unsubscribe
#
#
# TaskSentence:  For time's sake since I couldn't talk to you earlier, please meet w/Shari and /or Elizabeth regarding the priority issues in the spreadsheet below.
# Original summary: Meet with Shari or Elizabeth
#
#
# TaskSentence:  Everyone, pls forward to me ASAP your list of top customers you want invited to the Oct.
# Original summary: Forward top customer list to SENDER
#
#
# TaskSentence:  PLEASE CONFIRM THIS .
# Original summary: Confirm fix to contract
#
#
# TaskSentence:  Call me when your are ready and I will come by and pick it up.
# Original summary: Call SENDER about confirmation.
#
#
# TaskSentence:  Please respond to henri@hearme.com
# Original summary: Reply to henri@hearme.com
#
#
# TaskSentence:  please correct per your calculation
# Original summary: Correct it
#
#
# TaskSentence:  Please direct questions about this report to: Greg Shuttlesworth Email: greg@pira.com , Tom Howard EMail: tazh@pira.com , Richard Redash Email: Rich@pira.com , Nobu Tarui Email: nobuo@pira.com or Jane Hsu Email: jane@pira.com .
# Original summary: SEND questions to Greg Shuttlesworth at greg@pira.com
#
#
# TaskSentence:  Please donate this money to the funds set up to help repair the lives of those Americans hurt by Enron's underhanded dealings.
# Original summary: Donate this money
#
#
# TaskSentence:  Please get back to me with the selection.
# Original summary: Reply to SENDER with selection
#
#
# TaskSentence:  Please forward the TEPI gty for signature.
# Original summary: Forward TEPI gty for signature to SENDER
#
#
# TaskSentence:  Please take a look at the materials that Alan Comnes sent out earlier today so that we can discuss which charts/information should be included in Kean's materials packet.
# Original summary: Examine materials
#
#
# TaskSentence:  Please schedule your flight to arrive to the San Francisco airport on Monday, October 16th.
# Original summary: Schedule flight to San Francisco
#
#
# TaskSentence:  While you're waiting for the economy to rebound, take a look at some of the incredibly cheap bargains that are still available.
# Original summary: Look at bargains
#
#
# TaskSentence:  Please insert names and other information as appropriate.
# Original summary: Insert names in incumbency certificates
#
#
# TaskSentence:  Please call these folks and see if you can set up a meeting of the East Development team either Tuesday or Wednesday:
# Original summary: Call folks to set up meeting with East Development team
#
#
# TaskSentence:  Just please coordinate the format with Keith.
# Original summary: Coordinate format with Keith
#
#
# TaskSentence:  If you are not the intended recipient, please delete the e-mail and notify us immediately.
# Original summary: Delete this email and notify SENDER
#
#
# TaskSentence:  pls print for me on Monday--thanks.
# Original summary: Print this on Monday
#
#
# TaskSentence:  Please respond by 10 a.m. on Wednesday, March 14.
# Original summary: Reply to SENDER by 10 a.m. on Wednesday, March 14.
#
#
# TaskSentence:  Please review and email Michelle your comments to this paragraph.
# Original summary: Review paragraph and send comments to Michelle
#
#
# TaskSentence:  Can you please send us your excel spreadsheets that were used for generated the graphs??
# Original summary: Send excel spreadsheets to SENDER
#
#
# TaskSentence:  At your convenience, please review the attached.
# Original summary: Review the attached
#
#
# TaskSentence:  Please forward back with any changes you might make.
# Original summary: Forward spreadsheet back to SENDER with changes
#
#
# TaskSentence:  Please review and let me know if additional changes are required or recommended.
# Original summary: Review latest revision for Fountain Valley Project
#
#
# TaskSentence:  Please bring your adapter.
# Original summary: Bring adapter
#
#
# TaskSentence:  Please provide feedback on the employees listed below by accessing the Performance Management System PEP and completing an online feedback form as described in the Performance Management Quick Reference Guide .
# Original summary: Provide feedback
#
#
# TaskSentence:  Please acknowledge receipt.
# Original summary: Acknowledge receipt
#
#
# TaskSentence:  Gerald, could you please verify the entities & other missing information highlighted in the document.
# Original summary: Verify entities in document
#
#
# TaskSentence:  Please fill in where it is pertinent and monitor word count to 550.
# Original summary: Edit draft of Executive Letter and monitor word count
#
#
# TaskSentence:  Please make sure to write El Salvador on your check.
# Original summary: Write El Salvador on check
#
#
# TaskSentence:  Please contact him and arrange his travel.
# Original summary: Contact Todd Perry and arrange his travel for an interview
#
#
# TaskSentence:  Kay, please forward to Max Yzaguirre.
# Original summary: Forward this to Max Yzaguirre
#
#
# TaskSentence:  Nancy and Mike, please sign the attached and file it today, and deliver copies to those staff members who got copies of our initial filing.
# Original summary: Sign attached file and deliver copies to staff members
#
#
# TaskSentence:  I don't know what that means could you please clarify?
# Original summary: Clarify Meier Graefe
#
#
# TaskSentence:  Jim Coffey - Please call Zach at 1:30 PM.
# Original summary: Call Zach at 1:30 PM
#
#
# TaskSentence:  Please respond to lgibson@ogwb.com
# Original summary: Reply to lgibson@ogwb.com
#
#
# TaskSentence:  To discuss this action, please attend a floor meeting with Stan on Monday, January 7, from 1:30 - 2:30 in the Enron building in the area of 3922.
# Original summary: Attend floor meeting on Monday, January 7
#
#
# TaskSentence:  In reference to these surveys, please note: If you are allocating only infrastructure costs to some commercial teams listed in the survey, please identify them.
# Original summary: Identify commercial teams
#
#
# TaskSentence:  Take a look at the worksheet and give me a call.
# Original summary: Call SENDER about worksheet
#
#
# TaskSentence:  In light of this, please make sure your Confirmation copy includes the GTC.
# Original summary: Ensure confirmation copy includes the GTC
#
#
# TaskSentence:  plz respond with comments asap.
# Original summary: Reply with comments to SENDER
#
#
# TaskSentence:  At Alan's request, please provide to me by e-mail with a cc: to Alan by Thursday of this week your suggested changes to the March 2001 Monthly Report, so that we can issue the April 2001 Monthly Report by the end of this week.
# Original summary: Provide suggested changes to SENDER
#
#
# TaskSentence:  Also, please attend the dinner on Friday evening along with your wife if possible.
# Original summary: Attend dinner on Friday evening
#
#
# TaskSentence:  Please remove her from all mailing lists.
# Original summary: Remove Mary Hain from mail lists
#
#
# TaskSentence:  Please respond and tell me what you think.
# Original summary: Reply to SENDER about scheduling Christmas Dinner
#
#
# TaskSentence:  Can you help us by interviewing him in Sydney?
# Original summary: Interview him in Sydney
#
#
# TaskSentence:  Could you book a conference room for me on Thursday September 6th at 10am for about an hour.
# Original summary: Book a conference room
#
#
# TaskSentence:  Please plan on attending with me' thanks
# Original summary: Attend this with SENDER
#
#
# TaskSentence:  Employees on floors 33, 35, 44, 45, 46, and 47, please attend the floor meeting on Wednesday, February 6, from 9:30 - 10:30 near EB4712b.
# Original summary: Attend floor meeting on Wednesday February 6
#
#
# TaskSentence:  Please forward to Ms. Bobbi.
# Original summary: Forward this to Ms. Bobbi
#
#
# TaskSentence:  Please destroy your current card and replace it with the new wallet card upon receipt.
# Original summary: Destroy current card and replace
#
#
# TaskSentence:  Given the fact that an ISDA has not yet been sent out, could one of you please handle this?
# Original summary: Handle this
#
#
# TaskSentence:  Please send a package of article reprints to the attention of Joan Payne at the following address:
# Original summary: Send package of article reprints to Joan Payne
#
#
# TaskSentence:  Haedicke, Mark E. J , please arrange for a meeting.
# Original summary: Arrange for a meeting
#
#
# TaskSentence:  Please prepare a draft ISDA pursuant to the attached credit terms and deliver a draft to Eliot Bonner.
# Original summary: Prepare a draft ISDA and deliver to Eliot Bonner
#
#
# TaskSentence:  Can you please add Greg Whalley to the distribution on this report, which by the way is quite bebficial to us.
# Original summary: Add Greg halley to distribution on this report
#
#
# TaskSentence:  Please review and let me know your thoughts.
# Original summary: Review revisions
#
#
# TaskSentence:  Please take a minute to review the list and provide any bulleted information to my secretary, Joanne, at joanne.bennett@blakes.com.
# Original summary: Review group list for Project Stanley file
#
#
# TaskSentence:  Please send to Ben Jacoby once complete.
# Original summary: Send slide to Ben Jacoby
#
#
# TaskSentence:  Can you put pressure on New York?
# Original summary: Put pressure on New York
#
#
# TaskSentence:  Please access the following MS Word file and update the list for any individuals whom you want to receive a Xmas card from TW.
# Original summary: Access MS Word file and update the list
#
#
# TaskSentence:  can you help me wiht this?
# Original summary: Help SENDER
#
#
# TaskSentence:  Please respond to nmann@erac.com
# Original summary: Reply to nmann@erac.com
#
#
# TaskSentence:  Please respond whether we have your most updated information or if we are missing any information please update me accordingly.
# Original summary: Check whether information is updated
#
#
# TaskSentence:  Please plan to attend.
# Original summary: Attend Quarterly Legal Review QLR
#
#
# TaskSentence:  Daren would you look at the price for 29 and 30th of March 2000 .
# Original summary: Examine price for 29 and 30th of March 2000
#
#
# TaskSentence:  Can you call me on this one?
# Original summary: Call SENDER
#
#
# TaskSentence:  Please do give me a call with any comments on the documents or with any queries regarding timing.
# Original summary: Call SENDER with comments
#
#
# TaskSentence:  Please review and act upon this request.
# Original summary: Respond to this request
#
#
# TaskSentence:  Please review this Change Order and let me know if we can live with these warranty provisions.
# Original summary: Review Change Order
#
#
# TaskSentence:  Thanks and please call me if you have questions, comments, etc.
# Original summary: Call SENDER
#
#
# TaskSentence:  Please include the body of this message in any correspondence to PA Discount InkJet 050130 regarding this order.
# Original summary: Include body of this message in correspondences to PA Discount
#
#
# TaskSentence:  Please call me if we need to discuss.
# Original summary: Call SENDER
#
#
# TaskSentence:  Give me a call.
# Original summary: Call SENDER
#
#
# TaskSentence:  Please email me what you find out.
# Original summary: Send findings to SENDER
#
#
# TaskSentence:  Please post the JP MOrgan doc.
# Original summary: Post JP MOrgan doc.
#
#
# TaskSentence:  Please remove her from all your mail lists.
# Original summary: Remove Mary Hain from mail lists
#
#
# TaskSentence:  Please forward this to anyone who might benefit from a better understanding of energy derivatives, risk management, gas-to-electricity arbitrage, statistics or electric power trading.
# Original summary: Forward this to anyone who might benefit
#
#
# TaskSentence:  If you are not the intended recipient, please delete the e-mail and notify us immediately.
# Original summary: Delete this email and notify SENDER
#
#
# TaskSentence:  Please contact her to confirm.
# Original summary: Contact her to confirm
#
#
# TaskSentence:  Please call Brian Perrone 703-5616-486 or Scott Goodell at 713-8537-711 .
# Original summary: Call Perrone Brian Perrone at 703-5616-486 or Scott Goodell at 713-8537-711
#
#
# TaskSentence:  Please come to the Enron Lobby and ask for me or my assistant, Melinda McCarty.
# Original summary: Go to Enron Lobbby for SENDER
#
#
# TaskSentence:  Please prepare draft ISDA's for Oakleaf Waste Management, L.L.C. and Bison
# Original summary: Prepare draft ISDA's
#
#
# TaskSentence:  Please, call Shirley Crenshaw X3-5290 to coordinate and order sandwich you would like to have.
# Original summary: Coordinate with Shirley at X3-5290
#
#
# TaskSentence:  Please respond no later than Monday October 29.
# Original summary: Reply to SENDER by Monday October 29
#
#
# TaskSentence:  Please copy Joe's assistant Bernadette Hawkins with any E-mail comments.
# Original summary: Copy Bernadette Hawkins with E-mail comments
#
#
# TaskSentence:  Can you see if this is the correct CP.
# Original summary: Check this for correctness
#
#
# TaskSentence:  Would you let me know if this is what you're looking for?
# Original summary: Confirm this is correct
#
#
# TaskSentence:  If anyone needs help facilitating this process please coordinate with Chris Lambie 9746-780 .
# Original summary: Coordinate with Chris Lambie at 9746-780
#
#
# TaskSentence:  Please contact Tana Jones at X33399.
# Original summary: Contact Tana Jones at X33399.
#
#
# TaskSentence:  Can you add Ricardo.Perez@enron.com to this distribution list?
# Original summary: Add Ricardo.Perez@enron.com to this distribution list
#
#
# TaskSentence:  Please instruct Ms. Patel to fax Houston Exploration's executed Consent to my attention at 713-6463-490 .
# Original summary: Instruct Ms. Patel to fax Houston Exploration's executed Consent to SENDER at 713-6463-490
#
#
# TaskSentence:  Please contact the ISC Call Center at 713-3454-727 .
# Original summary: Call ISC Call Center at 713-3454-727
#
#
# TaskSentence:  Can you prepare a brief presentation that would serve as a discussion document for such a meeting.
# Original summary: Prepare presentation
#
#
# TaskSentence:  Lets go ahead and take the additional coverage, I think it
# Original summary: Take additional coverage
#
#
# TaskSentence:  So please respond now!
# Original summary: Respond to SENDER
#
#
# TaskSentence:  Can you check on this for us, too.
# Original summary: Check on this.
#
#
# TaskSentence:  Please look into this and let me know.
# Original summary: Investigate Tufco
#
#
# TaskSentence:  If you have any comments or questions please call me at 713-8533-399 or Mark Taylor, V.P.
# Original summary: Call SENDER at 713-8533-399
#
#
# TaskSentence:  For tickets please call Ryan Langan @ 503-7979-936 or e-mail @ ryan.langan@ripcity.com
# Original summary: Call Ryan Langan at 503-7979-936
#
#
# TaskSentence:  Please have the contract signed by JER Partners, a J.E.
# Original summary: Have JER Partners sign contract
#
#
# TaskSentence:  Note to approvers - please approve these expense reports quickly.
# Original summary: Approve expense reports
#
#
# TaskSentence:  Please respond to khairuddinmjaafar@petronas.com.my
# Original summary: Reply to khairuddinmjaafar@petronas.com.my
#
#
# TaskSentence:  Please respond to Darrell Duffie duffie@Stanford.EDU
# Original summary: Respond to Darrell Duffie at duffie@Stanford.EDU
#
#
# TaskSentence:  PLEASE REVIEW THE NOTICE AND DISCLAIMER BELOW
# Original summary: Review notice and disclaimer
#
#
# TaskSentence:  Also, could you please provide the pricing on this deal?
# Original summary: Provide pricing pricing on this deal
#
#
# TaskSentence:  Could you check this itenerary for Barry Tycholiz but make it refundable?
# Original summary: Check itinerary for Barry Tycholiz
#
#
# TaskSentence:  Kate, take a quick look at this would you?
# Original summary: Examine this
#
#
# TaskSentence:  As a result, will you overnight the sig pages and the incumbency certificate to Tremaine Wright?
# Original summary: Overnight sig pages and incumbency certificate to Tremaine Wright
#
#
# TaskSentence:  Joe: I need your help regarding the above counterparties
# Original summary: Help SENDER regarding counterparties
#
#
# TaskSentence:  TK could you update these prices for me for the Stan Presentation one more time - it's due to Tracy on Thurs ?
# Original summary: Update these prices
#
#
# TaskSentence:  Can you send it again?
# Original summary: Send this message to SENDER again
#
#
# TaskSentence:  If the NDA meets with your approval, please return a copy to me via fax no 713-6463-490 .
# Original summary: Send copy of NA to SENDER via fax
#
#
# TaskSentence:  could you please forward to Scott Miller email below our short confidentiality, non-solicitation and non-compete agreement?
# Original summary: Forward this to Scott Miller
#
#
# TaskSentence:  please schedule
# Original summary: Schedule this
#
#
# TaskSentence:  Please forward this information, and feel free to contact me if you have any additional concerns.
# Original summary: Contact SENDER about additional concerns
#
#
# TaskSentence:  can you look at this and let me know if it works.
# Original summary: Examine initial policy
#
#
# TaskSentence:  Kay, Please review the attached.
# Original summary: Review attached
#
#
# TaskSentence:  If we need to discuss this, give me a call.
# Original summary: Call SENDER
#
#
# TaskSentence:  Please forward your schedules to me for next week.
# Original summary: Forward schedule to SENDER
#
#
# TaskSentence:  Because of the limited amount of dial-in ports, please gather in groups and call from a land-line phone by 9:20 am CST.
# Original summary: Call from land-line in groups by 9:20 am CST
#
#
# TaskSentence:  Also, could you please have someone deliver to me EB 3892 the insurance form that I need or fax it to me at 6463-393 .
# Original summary: Have someone deliver insurance form to SENDER
#
#
# TaskSentence:  Please have them executed and return one of each for my files.
# Original summary: Exectute documents
#
#
# TaskSentence:  Can you please forward the presentation to Mog.
# Original summary: Forward presentation to Mog
#
#
# TaskSentence:  Please put this on my calendar, thanks
# Original summary: Put this on SENDER's calendar
#
#
# TaskSentence:  Please verify if this is some other c/p's deal.
# Original summary: Verify this is some other c/p's deal
#
#
# TaskSentence:  Please review the language in 87crfm.
# Original summary: Review language in 87crfm
#
#
# TaskSentence:  Can you locate the EBS Inc bylaws for me?
# Original summary: Locate the EBS Inc bylaws
#
#
# TaskSentence:  Please reference the order tracking number.
# Original summary: Reference order tracking number
#
#
# TaskSentence:  Shanna, can you check this out with Robert Jones.
# Original summary: Examine contract with Robert Jones
#
#
# TaskSentence:  Please contact Cathy Phillips X-36898 and let her know if you are interested in attending.
# Original summary: Contact Cathy about attending the annual Juvenile Diabetes Foundation Gala
#
#
# TaskSentence:  Please review and let me know if you have any questions.
# Original summary: Review draft of the LOI
#
#
# TaskSentence:  Could you email me the list of issues you have encountered thus far.
# Original summary: Send list of issues to SENDER
#
#
# TaskSentence:  Please match the purchase deal 551027 with sales deals 376880, 380492, and 551007 on CGAS.
# Original summary: Match purchase deal
#
#
# TaskSentence:  Could you please add Derek Baily dbailey to the TDS and sitara access list?
# Original summary: Add Derek Baily to access list
#
#
# TaskSentence:  Kimat, please forward to the Canadian Book Admin.
# Original summary: Forward deal ticket to Canadian Book Admin
#
#
# TaskSentence:  Interested candidates please respond to contact information listed below job description.
# Original summary: Respond to contact information
#
#
# TaskSentence:  TAFFY, PLS SEND ME TWO INITIALLED EXECUTION ORIGINALS OF THIS AMENDMENT.
# Original summary: Send initialled originals to SENDER
#
#
# TaskSentence:  Please prepare an amendment to the existing guaranties and have Enron execute a hardcopy original, delivering such copy to me at 2860b.
# Original summary: Amend existing guaranties and have Enron execute a hardcopy original
#
#
# TaskSentence:  Please respond to eldon
# Original summary: Reply to eldon
#
#
# TaskSentence:  Please comment,
# Original summary: Review Alberta PPA presentation
#
#
# TaskSentence:  If you are within 12 months of graduating and haven't already sent me an email, please reply letting me know you are eligible and interested in participating in registering for the fall 01 - spring 02 OCR program.?
# Original summary: Reply to SENDER about OCR program
#
#
# TaskSentence:  Please talk to Tracy and see if we need to update the credit terms and then send the latest SDG&E EEI Redline to Sharon Firooz, Tony Molnar and Jim Walsh at SDG&E.
# Original summary: Contact Tracy about updaing credit terms
#
#
# TaskSentence:  Please confirm whether this will work for you or propose an alternate day/time so I can make arrangements for a meeting room.
# Original summary: Confirm whether meeting at Tuesday at 10:00am will work
#
#
# TaskSentence:  Hyatt from 11:30 a.m. - 1:00 p.m. Please RSVP before Wednesday, August 30
# Original summary: RSVP
#
#
# TaskSentence:  Could you run a NX1 / NX3 report for our book.
# Original summary: Run a a NX1 / NX3 report
#
#
# TaskSentence:  Please send me any agenda items you'd like to cover in the next meeting by Monday, Oct. 2.
# Original summary: Send agenda items to SENDER
#
#
# TaskSentence:  Give me a call in January on this.
# Original summary: Call SENDER in January about this
#
#
# TaskSentence:  Please send me a copy of this document by e-mail or telefax once you have sent it out.
# Original summary: Send copy of this document to SENDER
