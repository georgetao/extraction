# %%
import pandas as pd

# %%
request_data = pd.read_csv('../data/Request_data.tsv', sep = '\t')

# %%
pd.set_option('display.max_colwidth', -1)

# %%
request_data.sample(20)
# Out:
#                                                                                                                                                                                                                   Sentence  \
# 4212  Also, don't forget to check out the current issue -- 20 newly designed -- at http://home.enron.com/pubs/enronbiz/2001/vol1/index.ht m
# 3387  Give me a call when you get a chance and we can run through that.
# 7925  Can you mail it Next Day Air also called Priority Mail?
# 5389  So please make sure these contacts switch to your new @enron.com address.
# 2763  Consequently, PLEASE RETAIN any and all documents, including all drafts, electronic documents, and email, that relate in any fashion to the 8K filing.
# 2434  Enron Corp. and Texaco Inc. currently have issued 12MM guaranties to Superior Natural Gas.
# 184   The media love him.
# ...

# %%
sum_data = pd.read_csv('../data/context_task_data.tsv', sep = '\t')

# %%
sum_data[['Context', 'TaskSentence', 'Summary']].sample(10)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                               Context  \
# 546   Please, if you know anything about Outlook or data recovery, I need your help.. I rely on e-mail not only for communication but to transfer and receive very important information - some of which will be lost permanently unless I am able to restore the files.. I also use my e-mail as a form of record keeping and information storage, which helps me to do my job.
# ...
